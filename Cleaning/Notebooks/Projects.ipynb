# %%
import matplotlib
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
FILE = '../Data/projects.csv'

# %%
df = pd.read_csv(FILE)

# %%
df.shape
# Out:
# (16972, 57)

# %%
df.head()
# Out:
#         id                    regionname  \
# 0  P154495                        Africa
# 1  P146666                        Africa
# 2  P154978         East Asia and Pacific
# 3  P157861  Middle East and North Africa
# 4  P132833                    South Asia
#
#                                          countryname prodline  \
# 0                                      Africa;Africa       RE
# 1      Republic of Cabo Verde;Republic of Cabo Verde       PE
# 2        Republic of Indonesia;Republic of Indonesia       RE
# 3  Hashemite Kingdom of Jordan;Hashemite Kingdom ...       RE
# 4  Democratic Socialist Republic of Sri Lan;Democ...       PE
#
#                    lendinginstr lendinginstrtype envassesmentcategorycode  \
# 0  Investment Project Financing               IN                        C
# 1  Investment Project Financing               IN                        B
# 2  Investment Project Financing               IN                        B
# ...
